# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 122.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 142.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 112.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]
# ...

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
# 1. Count the number of duplicate rows in the dataset
duplicate_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicate_count)

# 2. Display the first few duplicate rows to understand their structure
df[df.duplicated()].head()
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# ...

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
## Write your code here
# 1. Identify duplicate response patterns based on selected columns
selected_cols = ['MainBranch', 'Employment', 'RemoteWork']
pattern_duplicates = df.duplicated(subset=selected_cols).sum()
print(f"Number of duplicate patterns based on {selected_cols}: {pattern_duplicates}")

# 2. Analyze which other columns frequently share identical values within these groups
# We can find the most common combination groups
grouped_patterns = df.groupby(selected_cols).size().reset_index(name='count')
sorted_patterns = grouped_patterns.sort_values(by='count', ascending=False)
print("\nMost frequent identical response pattern groups:")
print(sorted_patterns.head())
# Out:
# Number of duplicate patterns based on ['MainBranch', 'Employment', 'RemoteWork']: 64876
#
# Most frequent identical response pattern groups:
#                         MainBranch  \
# 0   I am a developer by profession
# 2   I am a developer by profession
# 1   I am a developer by profession
# 78  I am a developer by profession
# 8   I am a developer by profession
#
#                                            Employment  \
# 0                                 Employed, full-time
# 2                                 Employed, full-time
# 1                                 Employed, full-time
# 78  Independent contractor, freelancer, or self-em...
# 8   Employed, full-time;Independent contractor, fr...
#
#                               RemoteWork  count
# 0   Hybrid (some remote, some in-person)  15286
# 2                                 Remote  12191
# 1                              In-person   7118
# 78                                Remote   2814
# ...

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
## Write your code here
import matplotlib.pyplot as plt

# Create a combined string label for the top duplicate response groups to plot clearly
top_patterns = sorted_patterns.head(10).copy()
top_patterns['Pattern_Label'] = top_patterns['MainBranch'].str[:25] + "\n(" + top_patterns['Employment'] + ")"

# Generate the visualization using pure matplotlib
plt.figure(figsize=(10, 6))
plt.barh(top_patterns['Pattern_Label'], top_patterns['count'], color='#4a90e2')

# Add titles and labels
plt.title('Top 10 Most Common Shared Survey Response Patterns', fontsize=14, fontweight='bold')
plt.xlabel('Number of Respondents', fontsize=12)
plt.ylabel('Response Combination Group', fontsize=12)
plt.gca().invert_yaxis()  # Put the highest count group at the top

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# ## Write your analysis here
# ### Data Insight Analysis
#
# Running the initial check for absolute duplicate rows across the entire dataset yields exactly 0 duplicates. This is because every observation contains a unique `Respondent` ID tracking number. This column guarantees that no two rows are technically 100% identical in the database ledger.
#
# When evaluating partial duplicates by excluding the unique identification index, significant response patterns emerge. Multiple survey entries match perfectly across categorical dimensions like `MainBranch`, `Employment`, and `RemoteWork`.
#
# These shared response clusters indicate that while there are no true broken duplicate records in the data architecture, there are distinct behavioral cohorts among the worldwide survey respondents who share identical professional traits.

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# * **Identification Phase:** The dataset was initially audited using `df.duplicated().sum()` to find absolute row duplicates. The result was 0 due to the unique `Respondent` tracking ID column. To find meaningful data redundancy, a partial duplicate check was conducted using `df.duplicated(subset=...)`, focusing on core professional features.
# * **Removal Phase:** To clean the dataset without altering unique records, `df.drop_duplicates(inplace=True)` was applied. This approach keeps the first occurrence of identical entries (`keep='first'`) while stripping away actual administrative duplicates, ensuring that data manipulation pipelines remain clean and free from structural bloat.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# * **Isolating System Identifiers:** The `Respondent` column was deliberately omitted or handled separately during validation checks. Because unique tracking keys are automatically incremented by survey platforms, including them in duplicate checks hides true data redundancy (e.g., a user clicking "Submit" twice and generating two different IDs for identical answers).
# * **Targeting High-Density Behavioral Metrics:** Core categorical variables—such as `MainBranch` (professional status), `Employment`, and `RemoteWork`—were isolated because they form the foundational profile of a respondent.
# * **Distinguishing Cohorts from Technical Errors:** Analyzing duplicates across a targeted subset of behavioral columns allows analysts to differentiate between an actual system logging error (identical answers across 80+ columns submitted at the exact same minute) and normal statistical clustering (two different people who happen to both be full-time remote developers).
# Use code with caution.Once you run this cell, this lab module is officially complete! Your next lab file in the capstone should be Handling Missing Values. Let me know if you would like to map out the code for checking df.isnull().sum() in that next module!AI responses may include mistakes. Current limitations only allow part of the document to be used for this answer. Learn more

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
